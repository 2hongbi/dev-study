# %%
import pandas as pd
import numpy as np
import requests
from sshtunnel import SSHTunnelForwarder
import psycopg2
from tqdm import tqdm
tqdm.pandas()
#import distance as dst

# %%
hotel = pd.read_excel('./data/2018_hotel_data_주소_위경도.xlsx') # 호텔 표본

# %%
def find_sido(table):
    sido_list= table['지번주소'].split()
    return sido_list[0]

# %%
hotel['시도'] =  hotel.progress_apply(lambda x : find_sido(x),axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1879/1879 [00:00<00:00, 69151.24it/s]

# %%
def find_sigungu(table):
    if table['시도'] == '세종특별자치시':
        pass
    else: 
        sigungu_list= table['지번주소'].split()
        if sigungu_list[2][-1] =='구':
            return sigungu_list[1]+' '+sigungu_list[2]
        else:
            return sigungu_list[1]

# %%
hotel['시군구'] =  hotel.progress_apply(lambda x : find_sigungu(x),axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1879/1879 [00:00<00:00, 47944.38it/s]

# %%
bunji_list = []
def find_bjdong(table):
    
    try:
        bjdong_list= table['지번주소'].split()
        if table['시도'] == '세종특별자치시':
            if len(bjdong_list) == 2:
                bunji_list.append(bjdong_list[2])
                return bjdong_list[1]
            elif len(bjdong_list) == 3:
                bunji_list.append(bjdong_list[3])
                return bjdong_list[1]+' '+bjdong_list[2]
        else:
            if len(bjdong_list) == 4:
                bunji_list.append(bjdong_list[3])
                return bjdong_list[2]
            else:
                if any(chr.isdigit() for chr in bjdong_list[3]):
                        bunji_list.append(bjdong_list[3])
                        return bjdong_list[2]
                else:
                     if bjdong_list[2][-1] =='구':
                        bunji_list.append(bjdong_list[4])
                        return bjdong_list[3]
                     else:
                        bunji_list.append(bjdong_list[4])
                        return bjdong_list[2]+' '+bjdong_list[3]

    except:
        pass

# %%
hotel['법정동'] =  hotel.progress_apply(lambda x : find_bjdong(x),axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1879/1879 [00:00<00:00, 46883.39it/s]

# %%
hotel['번지']= bunji_list

# %%
def find_bun(table):
    try:
        return str(table.번지.split('-')[0]).zfill(4)
        
    except:
        return str('0000').zfill(4)

# %%
hotel['번'] = hotel.progress_apply(lambda x : find_bun(x),axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1879/1879 [00:00<00:00, 52311.18it/s]

# %%
def find_ji(table):
    try:
        return str(table.번지.split('-')[1]).zfill(4)
        
    except:
        return str('0000').zfill(4)

# %%
hotel['지'] = hotel.progress_apply(lambda x : find_ji(x),axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1879/1879 [00:00<00:00, 62137.59it/s]

# %%
admin = pd.read_excel('./data/법정동_20211117.xlsx') #법정동 코드 맴핑을 위한 법정동파일 출처 : 행정표준코드관리시스템

# %%
def find_bjdong_code(table):
    try:
        if table['시도'] =='세종특별자치시':
            sido = admin[admin.시도명 == '세종특별자치시']
            bjdong_list = table.법정동.split()
            if len(bjdong_list) == 1:
                return sido[sido.읍면동명 ==table['법정동']].법정동코드.values[0]
            elif len(bjdong_list) == 2:
                sigungu= sido[sido.읍면동명 ==bjdong_list[0]]
                return sigungu[sigungu.동리명==bjdong_list[1]].법정동코드.values[0]
        
        
        sido = admin[admin.시도명 == table['시도']]
        sigungu = sido[sido.시군구명==table['시군구']]
        bjdong_list = table.법정동.split()
        #len(bjdong_list)
        if len(bjdong_list) == 1:
            return sigungu[sigungu.읍면동명 ==table['법정동']].법정동코드.values[0]
        elif len(bjdong_list) == 2:
            hjdong_list= sigungu[sigungu.읍면동명 ==bjdong_list[0]]
            return hjdong_list[hjdong_list.동리명==bjdong_list[1]].법정동코드.values[0]
    except:
        pass

# %%
hotel['bjdong_code'] = hotel.progress_apply(lambda x : find_bjdong_code(x),axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1879/1879 [00:04<00:00, 447.96it/s]

# %%
hotel[hotel['bjdong_code'].isna()]
# Out:
#       Unnamed: 0    번호 지역1(시도) 지역2(시군구)   세부업종                   호텔명(등록명칭)  \
# 70            70    71   서울특별시      강동구  관광호텔업                     투비인관광호텔
# 147          147   148   서울특별시      도봉구  관광호텔업                    더데이 관광호텔
# 462          462   463    경기도       수원시  관광호텔업  수원애경역사 주식회사\n(노보텔 앰배서더 수원)
# 472          472   473    경기도       수원시   호스텔업                  HOTEL EAST
# 473          473   474    경기도       수원시  가족호텔업                        마루호텔
# 477          477   478    경기도       수원시  가족호텔업                        유성호텔
# 479          479   480    경기도       수원시  가족호텔업                       상하이호텔
# 481          481   482    경기도       수원시  가족호텔업                         마루Ⅱ
# 485          485   486    경기도       수원시  가족호텔업                    호텔 잇츠더블유
# 580          580   581    경기도       안산시  관광호텔업                      하이비스호텔
# 599          599   600    경상남도      창원시  관광호텔업                     에비뉴관광호텔
# 600          600   601    경상남도      창원시  관광호텔업                    풀만앰배서더창원
# 607          607   608    경상남도      창원시  관광호텔업                    ㈜엘시티관광호텔
# 693          693   694    경상북도      포항시   호스텔업                 동빈나루 게스트하우스
# 776          776   777   대구광역시       남구  관광호텔업                ㈜이랜드파크 프린스호텔
# 799          799   800   대전광역시      유성구  관광호텔업                       호텔ICC
# 967          967   968   울산광역시      울주군  관광호텔업                   아마란스 관광호텔
# 1115        1115  1116    전라북도      전주시  관광호텔업                        르윈호텔
# 1117        1117  1118    전라북도      전주시  관광호텔업                        호텔한성
# 1119        1119  1120    전라북도      전주시  관광호텔업                 째즈어라운드 관광호텔
# 1120        1120  1121    전라북도      전주시  관광호텔업                 전주한옥태조궁관광호텔
# 1121        1121  1122    전라북도      전주시  관광호텔업                      풍남관광호텔
# 1125        1125  1126    전라북도      전주시  관광호텔업                      JS관광호텔
# 1127        1127  1128    전라북도      전주시  관광호텔업                    그랜드힐스턴호텔
# 1129        1129  1130    전라북도      전주시  소형호텔업                    황실한옥관광호텔
# 1131        1131  1132    전라북도      전주시   호스텔업                     일퍼센트호스텔
# 1132        1132  1133    전라북도      전주시   호스텔업                     갤러리 스테이
# 1133        1133  1134    전라북도      전주시   호스텔업                  말마니 게스트하우스
#
#        등급    객실수                                       주소  \
# 70    1성급   92.0                      서울특별시 강동구 천중로42길 75
# 147   1성급   60.0            서울특별시 도봉구 도봉동 903(도봉동, 더데이호텔)
# 462   4성급  287.0  경기도 수원시 팔달구 덕영대로 902 (매산로1가, 노보텔앰배서더수원)
# 472   NaN   21.0            경기도 수원시 팔달구 고화로9번길 25 (매산로2가)
# 473   NaN   32.0            경기도 수원시 팔달구 고화로9번길 33 (매산로2가)
# 477   NaN   90.0           경기도 수원시 팔달구 갓매산로25번길 3 (매산로2가)
# 479   NaN   71.0             경기도 수원시 팔달구 향교로3번길 52(매산로1가)
# 481   NaN   30.0             경기도 수원시 팔달구 고화로9번길 34(매산로2가)
# 485   NaN   47.0            경기도 수원시 팔달구 고화로13번길 23(매산로2가)
# 580   NaN   60.0                경기도 안산시 단원구 중앙대로 885(고잔동)
# 599   3성급   60.0            경상남도 창원시 의창구 용지로169번길 5 (용호동)
# 600   4성급  321.0              경상남도 창원시 의창구 원이대로 332 (대원동)
# 607   3성급   94.0          경상남도 창원시 마산합포구 해안대로 317 (신포동2가)
# 693   NaN    1.0                    경상북도 포항시 북구 해동로 211-1
# 776   1등급  117.0                         대구광역시 남구 명덕로 148
# 799   3성급   90.0               대전광역시 유성구 도룡동 엑스포로 123번길55
# 967   NaN   35.0                  울산광역시 울주군 상북면 덕현로 752-8
# 1115  3성급  166.0             전라북도 전주시 완산구 기린대로 81 (풍남동3가)
# 1117  2성급   40.0             전라북도 전주시 완산구 객사5길 43-3 (고사동)
# 1119  3성급   35.0            전라북도 전주시 덕진구 정언신로 182 (우아동2가)
# 1120  NaN   30.0            전라북도 전주시 완산구 전라감영로 40 (중앙동4가)
# 1121  NaN   63.0          전라북도 전주시 완산구 전주객사2길 45-7(다가동3가)
# 1125  2성급   59.0           전라북도 전주시 완산구 팔달로 212-9 (경원동3가)
# 1127  NaN  100.0            전라북도 전주시 완산구 온고을로 211 (효자동3가)
# 1129  2성급   20.0              전라북도 전주시 완산구 은행로 22 (풍남동1가)
# 1131  NaN   25.0         전라북도 전주시 완산구 전동성당길 12-14 (경원동1가)
# 1132  NaN   17.0           전라북도 전주시 완산구 동문길 54-23 (풍남동1가)
# 1133  NaN    9.0          전라북도 전주시 완산구 현무1길 21-27 (경원동3가)
#
#                                          지번주소  \
# 70                  서울 강동구 길동 388-2 길동투비인관광호텔
# 147                   서울 도봉구 도봉동 560-16 더데이호텔
# 462          경기도 수원시 팔달구 매산로1가 18-7 노보텔앰배서더수원
# 472                     경기도 수원시 팔달구 매산로2가 7-7
# 473                     경기도 수원시 팔달구 매산로2가 7-3
# 477                    경기도 수원시 팔달구 매산로2가 68-5
# 479                    경기도 수원시 팔달구 매산로1가 21-3
# 481                    경기도 수원시 팔달구 매산로2가 10-6
# 485        경기도 수원시 팔달구 매산로2가 9-6 HOTEL It's W
# 580                      경기 안산시 단원구 원시동 774-3
# 599              경상남도 창원시 의창구 용호동 73-28 호텔에비뉴
# 600   경상남도 창원시 의창구 대원동 122 그랜드 머큐어 앰배서더 창원 호텔
# 607         경상남도 창원시 마산합포구 신포동2가 117-34 리베라호텔
# 693                    경상북도 포항시 북구 동빈2가 144-8
# 776                      대구광역시 남구 대명2동 1824-2
# 799                     대전 유성구 도룡동 4-29 호텔ICC
# 967                       울산 울주군 상북면 덕현리 72-2
# 1115                   전라북도 전주시 완산구 풍남동3가 9-7
# 1117                      전북 전주시 완산구 고사동  199
# 1119                 전라북도 전주시 덕진구 우아동2가 921-7
# 1120                  전라북도 전주시 완산구 중앙동4가 31-7
# 1121           전라북도 전주시 완산구 다가동3가 43-2 풍남관광호텔
# 1125        전라북도 전주시 완산구 경원동3가 32-22 전주JS관광호텔
# 473     수원시 팔달구      팔달구   매산로2가  매산로2가  0000          NaN
# 477     수원시 팔달구      팔달구   매산로2가  매산로2가  0000          NaN
# 479     수원시 팔달구      팔달구   매산로1가  매산로1가  0000          NaN
# 481     수원시 팔달구      팔달구   매산로2가  매산로2가  0000          NaN
# 485     수원시 팔달구      팔달구   매산로2가  매산로2가  0000          NaN
# 580     안산시 단원구      원시동   774-3   0774  0003          NaN
# 599     창원시 의창구      용호동   73-28   0073  0028          NaN
# 600     창원시 의창구      대원동     122   0122  0000          NaN
# 607   창원시 마산합포구    마산합포구   신포동2가  신포동2가  0000          NaN
# 693      포항시 북구       북구    동빈2가   동빈2가  0000          NaN
# 776          남구     대명2동  1824-2   1824  0002          NaN
# 799         유성구      도룡동    4-29   0004  0029          NaN
# 967         울주군  상북면 덕현리    72-2   0072  0002          NaN
# 1115    전주시 완산구      완산구   풍남동3가  풍남동3가  0000          NaN
# 1117    전주시 완산구      고사동     199   0199  0000          NaN
# 1119    전주시 덕진구      덕진구   우아동2가  우아동2가  0000          NaN
# 1120    전주시 완산구      완산구   중앙동4가  중앙동4가  0000          NaN
# 1121    전주시 완산구      완산구   다가동3가  다가동3가  0000          NaN
# 1125    전주시 완산구      완산구   경원동3가  경원동3가  0000          NaN
# 1127    전주시 완산구      완산구   효자동3가  효자동3가  0000          NaN
# 1129    전주시 완산구      완산구   풍남동1가  풍남동1가  0000          NaN
# 1131    전주시 완산구      완산구   경원동1가  경원동1가  0000          NaN
# 1132    전주시 완산구      완산구   풍남동1가  풍남동1가  0000          NaN
# 1133    전주시 완산구      완산구   경원동3가  경원동3가  0000          NaN

# %%
hotel[hotel['bjdong_code'].isna()].index
# Out:
# Int64Index([ 477,  479,  481,  485,  580,  599,  600,  607,  693,  776,  799,
#              967, 1115, 1117, 1119, 1120, 1121, 1125, 1127, 1129, 1131, 1132,
#             1133],
#            dtype='int64')

# %%
hotel.loc[481]
# Out:
# Unnamed: 0                              481
# 번호                                      482
# 지역1(시도)                                경기도
# 지역2(시군구)                                수원시
# 세부업종                                  가족호텔업
# 호텔명(등록명칭)                               마루Ⅱ
# 등급                                      NaN
# 객실수                                    30.0
# 주소             경기도 수원시 팔달구 고화로9번길 34(매산로2가)
# 지번주소                 경기도 수원시 팔달구 매산로2가 10-6
# 도로명주소                 경기도 수원시 팔달구 고화로9번길 34
# 위도                                37.269787
# 경도                               127.006192
# 시도                                      경기도
# 시군구                                 수원시 팔달구
# 법정동                                     팔달구
# 번지                                    매산로2가
# 번                                     매산로2가
# 지                                      0000
# bjdong_code                             NaN
# Name: 481, dtype: object

# %%
hotel['bjdong_code'][481] = '4111513500'
# Out:
# C:\Users\LEESOY~1\AppData\Local\Temp/ipykernel_20128/2202278788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel['bjdong_code'][479] = '4111513400'

# %%
def make_pnu(table):
        return str(int(table['bjdong_code']))+'-0-'+str(table['번']).zfill(4)+str(table['지']).zfill(4)

# %%
hotel['PNU'] = hotel.progress_apply(lambda x : make_pnu(x), axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2301/2301 [00:00<00:00, 43000.01it/s]

# %%
hotel.to_excel('./export_data/hotel_2021_11_29_vol6.xlsx',index=False)
