# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# https://www.modetour.com/Livebooking/Hotel3/List.aspx# : 강릉, 호텔 이름 순으로만 검색해도 무방
# 결과 창 : https://www.modetour.com/Livebooking/Hotel3/Detail.aspx?smallUrlKey=03d06920b17e9cae, 12/6 ~ 12/8


# 객실 정보 드문드문 있음
URL = 'https://www.modetour.com/Livebooking/Hotel3/Detail.aspx?smallUrlKey=df57d997b8c3a2a2'

html = urlopen(URL)
bs = BeautifulSoup(html, "lxml", from_encoding='utf-8')

# %%
bs
# Out:
# <!DOCTYPE html>
# <!--[if IE 8 ]><html class="ie8 ie no-js" lang="ko"> <![endif]--><!--[if IE 9 ]><html class="ie9 ie no-js" lang="ko"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html lang="ko"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>다시 만나고 싶은 여행 - 모두투어 자유여행</title>
# <meta content="모두투어, 여행사, 해외여행, 해외항공, 동남아여행, 중국여행, 일본여행, 미주여행, 남태평양여행, 유럽여행, 인도여행, 아프리카 여행, 골프여행, 패키지, 에어텔, 허니문, 자유여행, 골프여행, jm프리미엄, 크루즈, 국내여행, 제주여행, 호텔, 숙박, 해외호텔, 국내숙박, 항공권 ,해외항공권 ,국내항공권, 철도 ,패스, 여행정보, 추천여행사, 최저가항공권" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="//img.modetour.co.kr/event_14/0528_talk/talk_main.jpg" property="og:image"/>
# <meta content="모두투어 - 자격있는 여행전문가" property="og:description"/>
# <meta content="대한민국 여행의 기준이 되다! 모두투어는 해외여행, 국내여행, 패키지여행, 에어텔, 항공권, 호텔 등 각종 여행정보를 제공하는 국내 최대 여행포탈사이트 입니다." name="description"/>
# ...

# %%
# 갖고 와야 하느 것 : 호텔명, 호텔명(영문), 객실평형, (해당 객실 평형의) 객실이름,  주중요금
html_content = bs.prettify()

# %%
html_content
# Out:
# '<!DOCTYPE html>\n<!--[if IE 8 ]><html class="ie8 ie no-js" lang="ko"> <![endif]-->\n<!--[if IE 9 ]><html class="ie9 ie no-js" lang="ko"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!-->\n<html lang="ko">\n <!--<![endif]-->\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <title>\n   다시 만나고 싶은 여행 - 모두투어 자유여행\n  </title>\n  <meta content="모두투어, 여행사, 해외여행, 해외항공, 동남아여행, 중국여행, 일본여행, 미주여행, 남태평양여행, 유럽여행, 인도여행, 아프리카 여행, 골프여행, 패키지, 에어텔, 허니문, 자유여행, 골프여행, jm프리미엄, 크루즈, 국내여행, 제주여행, 호텔, 숙박, 해외호텔, 국내숙박, 항공권 ,해외항공권 ,국내항공권, 철도 ,패스, 여행정보, 추천여행사, 최저가항공권" name="keywords"/>\n  <meta content="website" property="og:type"/>\n  <meta content="//img.modetour.co.kr/event_14/0528_talk/talk_main.jpg" property="og:image"/>\n  <meta content="모두투어 - 자격있는 여행전문가" property="og:description"/>\n  <meta content="대한민국 여행의 기준이 되다! 모두투어는 해외여행, 국내여행, 패키지여행, 에어텔, 항공권, 호텔 등 각종 여행정보를 제공하는 국내 최대 여행포탈사이트 입니다." nam
# ...

# %%
# 호텔명
kor_nm = bs.find('span', {'class': 'korea'}).text
kor_nm
# Out:
# '더 홍씨호텔 강릉'

# %%
# 호텔명(영문)

eng_nm = bs.find('span', {'class': 'eng'}).text
eng_nm
# Out:
# 'The HongC Hotel Gangneung'

# %%
bs.find_all('span', {'class': 'sub_tit'})
# Out:
# [<span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
#  <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>,
# ...

# %%
bs.select('#trRoom_0 > td:nth-child(1) > div > div > div.cont > span')
# Out:
# [<span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>]

# %%
# 객실평형
room = bs.find('tr', {'id': 'trRoom_0'})

# %%
# 객실 이름
room_nm = room.find('span', {'class': 'r_tit'}).text

# %%
room_nm
# Out:
# 'Deluxe Double Ocean View'

# %%
# 주중 요금
room_price = room.find('span', {'class': 'price_01'}).text

# %%
room_price
# Out:
# '793,850원'

# %%
# 객실 정보 레이어
room_info_layer = room.find('div', {'class': 'cont'})

# %%
room_info_layer
# Out:
# <div class="cont">
# <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>
# <ul>
# <li>Relax - In-room massage available</li>
# <li>Internet - Free WiFi and wired Internet access</li>
# <li>Entertainment - 26-inch flat-screen TV with digital channels and pay movies</li>
# <li>Food&amp;Drink - Refrigerator, room service, and free bottled water</li>
# </ul>
# </div>

# %%
area
# Out:
# <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>

# %%
t = bs.find('div', {'class': 'cont'})

# %%
print(t)
# Out:
# <div class="cont">
# <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>
# <ul>
# <li>Relax - In-room massage available</li>
# <li>Internet - Free WiFi and wired Internet access</li>
# <li>Entertainment - 26-inch flat-screen TV with digital channels and pay movies</li>
# <li>Food&amp;Drink - Refrigerator, room service, and free bottled water</li>
# </ul>
# </div>

# %%
test = '23 제곱미터 크기의 객실, 시내 전망'

# %%
test2 = '인터넷 - 무료 WiFi 엔터테인먼트 - 케이블 채널 시청이 가능한 평면 TV 식음료 - 냉장고, 전기 주전자 및 무료 생수'

# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm
import chromedriver_autoinstaller
import time
from numpy import dot
import requests
import json
import difflib
import sys
from numpy.linalg import norm
import numpy as np
import re
tqdm.pandas()

# %%
path = chromedriver_autoinstaller.install() # 크롬 드라이버 install
driver = webdriver.Chrome(path) 
#driver.get('https://kbland.kr/')
driver.get('https://www.modetour.com/Livebooking/Hotel3/Detail.aspx?smallUrlKey=522a6aeff95bfade') 
time.sleep(7)
# driver.find_element_by_class_name('sub_tit').click() #지역설정을 위한 클릭

# driver.find_element_by_xpath('/html/body/div[3]/div[5]/div[2]/div[2]/div[3]/table/tbody/tr[1]/td[1]/div/a').click()

# driver.execute_script("document.querySelector('.room_info_layer').style='display: block';")
element = driver.find_element_by_class_name('room_info_layer')

# element가 display=none;인걸로..
driver.execute_script("arguments[0].style.display='block';", element)

time.sleep(2)
req = driver.page_source
soup=BeautifulSoup(req, 'html.parser')
room= soup.select_one('.sub_tit')
print(room)
# Out:
# C:\Users\LEESOY~1\AppData\Local\Temp/ipykernel_10980/3596209054.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# C:\Users\LEESOY~1\AppData\Local\Temp/ipykernel_10980/3596209054.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element = driver.find_element_by_class_name('room_info_layer')
# <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>

# %%
path = chromedriver_autoinstaller.install() # 크롬 드라이버 install
driver = webdriver.Chrome(path) 
#driver.get('https://kbland.kr/')
driver.get('https://www.modetour.com/Livebooking/Hotel3/Detail.aspx?smallUrlKey=522a6aeff95bfade') 
time.sleep(7)
#driver.find_element_by_class_name('sub_tit').click() #지역설정을 위한 클릭
#driver.find_element_by_xpath('/html/body/div[3]/div[5]/div[2]/div[2]/div[3]/table/tbody/tr[8]/td[1]/div/a').click()
time.sleep(2)
req = driver.page_source
soup=BeautifulSoup(req, 'html.parser')
room= soup.select_one('.sub_tit')
print(room)
# Out:
# <span class="sub_tit">2 Twin Beds and 1 Twin Sofa Bed</span>

# %%
import random

path = chromedriver_autoinstaller.install() # 크롬 드라이버 install
driver = webdriver.Chrome(path) 

driver.implicitly_wait(5)

driver.get('https://www.modetour.com/Livebooking/Hotel3/Detail.aspx?smallUrlKey=522a6aeff95bfade') 
time.sleep(random.uniform(2, 4))
#driver.find_element_by_class_name('sub_tit').click() #지역설정을 위한 클릭
#driver.find_element_by_xpath('/html/body/div[3]/div[5]/div[2]/div[2]/div[3]/table/tbody/tr[8]/td[1]/div/a').click()

time.sleep(random.uniform(2,4)) 
req = driver.page_source
soup=BeautifulSoup(req, 'html.parser')


time.sleep(random.uniform(2, 4))

# checkin date 변경
driver.find_element_by_xpath("""//td[@title="2021-12-20"]""").click()

time.sleep(random.uniform(2, 4))

# checkout date 변경
driver.find_element_by_xpath("""//td[@title="2021-12-22"]""").click()

driver.find_element_by_xpath("/html/body/div[3]/div[5]/div[2]/div[2]/form/div/div/a/span").click()

room_detail_btn = soup.select_one('.room_detail_info')
print(room_detail_btn)
print(room_detail_btn.is_displayed())
# Out:
#   File "C:\Users\LEESOY~1\AppData\Local\Temp/ipykernel_3676/2159912047.py", line 32
#     print(room_detail_btn.is_displayed())
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal
